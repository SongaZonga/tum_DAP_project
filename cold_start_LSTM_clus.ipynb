# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import sqlite3

# %%
input_file="20230411_SummerTerm23_Data_Challenge_Infineon_Data.csv"
date_column_name = 'reporting_time'

# Loading of dataset
df_origin = pd.read_csv(input_file, parse_dates=['reporting_time'])

#delete discontinuing products
df_continue = df_origin[df_origin['reporting_time']=='2023-02-01T00:00:00.000Z'].copy()
df_continue_origin = df_origin[df_origin['product_name'].isin(df_continue['product_name'])].copy()

df_continue_origin['reporting_time'] = pd.to_datetime(df_continue_origin['reporting_time'], utc=True)
df_continue_origin['reporting_time'] = df_continue_origin['reporting_time'].dt.tz_localize(None)
df_continue_origin.set_index('reporting_time', inplace=True)
df_continue_origin['product_application'] = df_continue_origin['product_application'].fillna('nan')
sub_df = df_continue_origin

# %%
# importing clusters from clustering ipynb
df_clus = pd.read_csv('cluster30.csv')
sub_df = sub_df.reset_index()
sub_df = sub_df.merge(df_clus[['product_name', 'cluster']], on='product_name')
sub_df['cluster'] = sub_df['cluster'].astype(str)
sub_df.set_index('reporting_time', inplace=True)

# %%
sub_df.product_application.unique()
# Out:
# array(['gelb', 'rot', 'blau'], dtype=object)

# %%
all_app_list = ['product_application', list(sub_df.product_application.unique())]
all_fam_list = ['product_main_family', list(sub_df.product_main_family.unique())]
all_mkt_list = ['product_marketing_name', list(sub_df.product_marketing_name.unique())]
all_bsc_list = ['product_basic_type', list(sub_df.product_basic_type.unique())]
all_cls_list = ['cluster', [str(x) for x in list(sub_df.cluster.unique())]]

# %%
conn = sqlite3.connect('metadata.db')
cur = conn.cursor()


def add_to_db(df, cat_list):
    print(cat_list[0])
    for name in cat_list[1]:
        tab_name = cat_list[0] + "_" + name
        cur.execute(f'CREATE TABLE IF NOT EXISTS {tab_name} (demand INT(255))')
        series_pd = create_table(df=df, category=cat_list[0], sub_category=name, target='demand')
        series_pd.to_sql(tab_name, conn, if_exists='replace', index=True)

def create_table(df, category, sub_category, target):
    sub_set = df[df[category]==sub_category].copy()
    agg_series =  sub_set[target].resample('M').mean()
    return agg_series

cats = [all_app_list, all_fam_list, all_mkt_list, all_bsc_list, all_cls_list]

for cat in cats:
    add_to_db(df=sub_df, cat_list=cat)


conn.commit()
cur.close()
conn.close()
# Out:
# product_application
# product_main_family
# product_marketing_name
# product_basic_type
# cluster

# %%
conn = sqlite3.connect('metadata.db')
db_tables = pd.read_sql("""select * from sqlite_master where type="table" and name !='sqlite_sequence';""", con=conn)

# %%
tables = {}
db_tables.name
for table_name in db_tables.name:
    table = pd.read_sql("select * from " + table_name, con=conn)
    print(table_name)
    table = table.set_index('reporting_time')
    tables[table_name] = table
# Out:
# product_application_gelb
# product_application_rot
# product_application_blau
# product_main_family_E
# product_main_family_H
# product_main_family_D
# product_main_family_A
# product_main_family_C
# product_main_family_L
# product_main_family_B
# product_main_family_N
# product_main_family_M
# product_main_family_F
# product_main_family_G
# product_main_family_J
# product_main_family_O
# product_main_family_S
# product_main_family_Q
# product_main_family_T
# product_main_family_K
# product_main_family_W
# product_main_family_Z
# product_main_family_R
# product_main_family_U
# product_main_family_I
# product_main_family_Other
# product_marketing_name_hund
# product_marketing_name_katze
# product_marketing_name_maus
# product_marketing_name_fisch
# product_basic_type_BT124
# product_basic_type_BT121
# product_basic_type_BT282
# product_basic_type_BT352
# product_basic_type_BT283
# product_basic_type_BT346
# product_basic_type_BT348
# product_basic_type_BT281
# product_basic_type_BT143
# product_basic_type_BT369
# product_basic_type_BT147
# product_basic_type_BT370
# product_basic_type_BT363
# product_basic_type_BT280
# product_basic_type_BT243
# product_basic_type_BT374
# product_basic_type_BT371
# product_basic_type_BT148
# product_basic_type_BT364
# product_basic_type_BT372
# product_basic_type_BT365
# product_basic_type_BT373
# product_basic_type_BT366
# product_basic_type_BT367
# product_basic_type_BT368
# product_basic_type_BT127
# product_basic_type_BT311
# product_basic_type_BT328
# product_basic_type_BT312
# product_basic_type_BT313
# product_basic_type_BT329
# product_basic_type_BT322
# product_basic_type_BT330
# product_basic_type_BT323
# product_basic_type_BT314
# product_basic_type_BT331
# product_basic_type_BT315
# product_basic_type_BT332
# product_basic_type_BT316
# product_basic_type_BT333
# product_basic_type_BT299
# product_basic_type_BT391
# product_basic_type_BT383
# product_basic_type_BT384
# product_basic_type_BT385
# product_basic_type_BT166
# product_basic_type_BT167
# product_basic_type_BT245
# product_basic_type_BT75
# product_basic_type_BT77
# product_basic_type_BT84
# product_basic_type_BT266
# product_basic_type_BT248
# product_basic_type_BT268
# product_basic_type_BT269
# product_basic_type_BT118
# product_basic_type_BT119
# product_basic_type_BT125
# product_basic_type_BT130
# product_basic_type_BT337
# product_basic_type_BT338
# product_basic_type_BT339
# product_basic_type_BT340
# product_basic_type_BT98
# product_basic_type_BT342
# product_basic_type_BT109
# product_basic_type_BT100
# product_basic_type_BT343
# product_basic_type_BT82
# product_basic_type_BT110
# product_basic_type_BT108
# product_basic_type_BT344
# product_basic_type_BT83
# product_basic_type_BT105
# product_basic_type_BT305
# product_basic_type_BT306
# product_basic_type_BT307
# product_basic_type_BT117
# product_basic_type_BT308
# product_basic_type_BT122
# product_basic_type_BT309
# product_basic_type_BT120
# product_basic_type_BT357
# product_basic_type_BT358
# product_basic_type_BT355
# product_basic_type_BT356
# product_basic_type_BT351
# product_basic_type_BT353
# product_basic_type_BT349
# product_basic_type_BT350
# product_basic_type_BT91
# product_basic_type_BT93
# product_basic_type_BT92
# product_basic_type_BT88
# product_basic_type_BT89
# product_basic_type_BT90
# product_basic_type_BT107
# product_basic_type_BT359
# product_basic_type_BT111
# product_basic_type_BT345
# product_basic_type_BT347
# product_basic_type_BT162
# product_basic_type_BT86
# product_basic_type_BT163
# product_basic_type_BT164
# product_basic_type_BT253
# product_basic_type_BT165
# product_basic_type_BT254
# product_basic_type_BT168
# product_basic_type_BT300
# product_basic_type_BT327
# product_basic_type_BT112
# product_basic_type_BT263
# product_basic_type_BT264
# product_basic_type_BT246
# product_basic_type_BT265
# product_basic_type_BT341
# product_basic_type_BT267
# product_basic_type_BT78
# product_basic_type_BT101
# product_basic_type_BT317
# product_basic_type_BT275
# product_basic_type_BT318
# product_basic_type_BT271
# product_basic_type_BT272
# product_basic_type_BT273
# product_basic_type_BT304
# product_basic_type_BT123
# product_basic_type_BT116
# product_basic_type_BT386
# product_basic_type_BT389
# product_basic_type_BT390
# product_basic_type_BT128
# product_basic_type_BT129
# product_basic_type_BT274
# product_basic_type_BT276
# product_basic_type_BT354
# product_basic_type_BT277
# product_basic_type_BT278
# product_basic_type_BT326
# product_basic_type_BT321
# product_basic_type_BT301
# product_basic_type_BT302
# product_basic_type_BT150
# product_basic_type_BT154
# product_basic_type_BT155
# product_basic_type_BT252
# product_basic_type_BT325
# product_basic_type_BT319
# product_basic_type_BT320
# product_basic_type_BT334
# product_basic_type_BT310
# product_basic_type_BT335
# product_basic_type_BT261
# product_basic_type_BT244
# product_basic_type_BT85
# product_basic_type_BT336
# product_basic_type_BT262
# product_basic_type_BT76
# product_basic_type_BT381
# product_basic_type_BT303
# product_basic_type_BT113
# product_basic_type_BT114
# product_basic_type_BT115
# product_basic_type_BT388
# product_basic_type_BT144
# product_basic_type_BT126
# product_basic_type_BT360
# product_basic_type_BT361
# product_basic_type_BT362
# product_basic_type_BT149
# product_basic_type_BT151
# product_basic_type_BT152
# product_basic_type_BT153
# product_basic_type_BT135
# product_basic_type_BT145
# product_basic_type_BT156
# product_basic_type_BT131
# product_basic_type_BT171
# product_basic_type_BT176
# product_basic_type_BT138
# product_basic_type_BT296
# product_basic_type_BT133
# product_basic_type_BT142
# product_basic_type_BT294
# product_basic_type_BT134
# product_basic_type_BT157
# product_basic_type_BT146
# product_basic_type_BT289
# product_basic_type_BT136
# product_basic_type_BT137
# product_basic_type_BT293
# product_basic_type_BT169
# product_basic_type_BT288
# product_basic_type_BT140
# product_basic_type_BT141
# product_basic_type_BT170
# product_basic_type_BT292
# product_basic_type_BT287
# product_basic_type_BT132
# product_basic_type_BT177
# product_basic_type_BT179
# product_basic_type_BT180
# product_basic_type_BT158
# product_basic_type_BT159
# product_basic_type_BT173
# product_basic_type_BT160
# product_basic_type_BT295
# product_basic_type_BT290
# product_basic_type_BT175
# product_basic_type_BT178
# product_basic_type_BT286
# product_basic_type_BT174
# product_basic_type_BT181
# product_basic_type_BT285
# product_basic_type_BT139
# product_basic_type_BT172
# product_basic_type_BT291
# product_basic_type_BT58
# product_basic_type_BT59
# product_basic_type_BT60
# product_basic_type_BT54
# product_basic_type_BT56
# product_basic_type_BT57
# product_basic_type_BT61
# product_basic_type_BT47
# product_basic_type_BT48
# product_basic_type_BT49
# product_basic_type_BT50
# product_basic_type_BT51
# product_basic_type_BT52
# product_basic_type_BT53
# product_basic_type_BT62
# product_basic_type_BT63
# product_basic_type_BT64
# product_basic_type_BT65
# product_basic_type_BT66
# product_basic_type_BT67
# product_basic_type_BT55
# product_basic_type_BT68
# product_basic_type_BT69
# product_basic_type_BT70
# product_basic_type_BT71
# product_basic_type_BT72
# product_basic_type_BT73
# product_basic_type_BT74
# product_basic_type_BT407
# product_basic_type_BT190
# product_basic_type_BT418
# product_basic_type_BT195
# product_basic_type_BT420
# product_basic_type_BT197
# product_basic_type_BT194
# product_basic_type_BT419
# product_basic_type_BT208
# product_basic_type_BT216
# product_basic_type_BT209
# product_basic_type_BT217
# product_basic_type_BT218
# product_basic_type_BT215
# product_basic_type_BT255
# product_basic_type_BT256
# product_basic_type_BT257
# product_basic_type_BT258
# product_basic_type_BT247
# product_basic_type_BT249
# product_basic_type_BT250
# product_basic_type_BT102
# product_basic_type_BT103
# product_basic_type_BT104
# product_basic_type_BT106
# product_basic_type_BT87
# product_basic_type_BT403
# product_basic_type_BT96
# product_basic_type_BT97
# product_basic_type_BT99
# product_basic_type_BT94
# product_basic_type_BT95
# product_basic_type_BT81
# product_basic_type_BT259
# product_basic_type_BT260
# product_basic_type_BT251
# cluster_2
# cluster_6
# cluster_5
# cluster_0
# cluster_4
# cluster_3
# cluster_1

# %%
input_dict = {'product_application': 'blau', 'product_main_family':'K', 'product_marketing_name':'maus', 'product_basic_type': 'BT66', 'cluster':'0'}

new_prod_df = pd.DataFrame()
for key, value in input_dict.items():
    # print(key, value)
    tab = tables[key+'_'+value].rename({'demand':f"{value}_demand"}, axis = 1)
    new_prod_df = pd.concat((new_prod_df, tab), axis=1)

# %%
conn.close()

# %% [markdown]
# LSTM

# %% [markdown]
# Get sample of 100

# %%
import random
no_months = 30
# m_50_df = df_continue_origin[df_continue_origin.groupby('product_name').product_name.transform('count')>=no_months].copy()
rand_prods = random.choices(list(df_clus.product_name.unique()), k = 100)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
import tensorflow as tf

results_df = pd.DataFrame()
smape_list = []

def smape_loss(y_true, y_pred):
    y_true = tf.convert_to_tensor(y_true, dtype=tf.float32)
    y_pred = tf.convert_to_tensor(y_pred, dtype=tf.float32)

    numerator = tf.reduce_sum(tf.abs(y_true - y_pred))
    denominator = tf.reduce_sum(y_true + y_pred)

    return numerator / denominator


for prod in rand_prods:
    prod_features = sub_df[sub_df['product_name']==prod].max()
    input_dict = {'product_application': prod_features['product_application'], 'product_main_family':prod_features['product_main_family'],
                  'product_marketing_name':prod_features['product_marketing_name'], 'product_basic_type': prod_features['product_basic_type'],
                  'cluster':prod_features['cluster']}
    
    new_prod_df = pd.DataFrame()
    for key, value in input_dict.items():
        print(key, value)
        tab = tables[key+'_'+value].rename({'demand':f"{value}_demand"}, axis = 1)
        new_prod_df = pd.concat((new_prod_df, tab), axis=1)

    new_prod_df['mean_demand'] = new_prod_df.mean(axis=1, skipna=True)

    # Load your demand data into a DataFrame
    df = new_prod_df

    # Preprocess the data
    scaler = MinMaxScaler()
    df['ScaledDemand'] = scaler.fit_transform(df['mean_demand'].values.reshape(-1, 1))

    # Split the data into training and testing sets
    train_data, test_data = train_test_split(df['ScaledDemand'].values, test_size=0.2, shuffle=False)

    # Define the number of time steps to consider for each input sample
    timesteps = 5

    # Prepare the training data
    X_train = []
    y_train = []
    for i in range(timesteps, len(train_data)):
        X_train.append(train_data[i - timesteps:i])
        y_train.append(train_data[i])
    

    # Convert the training data to numpy arrays
    X_train, y_train = np.array(X_train), np.array(y_train)
    # print(X_train.shape[0], X_train.shape[1])


    # Reshape the training data to match LSTM input shape (samples, timesteps, features)
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
    # X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
    print('shaped')

    # Build the LSTM model
    model = Sequential()
    model.add(LSTM(units=64, input_shape=(timesteps, 1)))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    model.compile(optimizer='adam', loss=smape_loss)
    print('built')

    # Train the model
    model.fit(X_train, y_train, epochs=10, batch_size=32)

    # Prepare the test data
    X_test = []
    y_test = []
    for i in range(timesteps, len(test_data)):
        X_test.append(test_data[i - timesteps:i])
        y_test.append(test_data[i])

    # Convert the test data to numpy arrays
    X_test, y_test = np.array(X_test), np.array(y_test)
    # print(X_test.shape)

    # Reshape the test data to match LSTM input shape (samples, timesteps, features)
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

    # Make predictions on the test data
    predictions = model.predict(X_test)

    # Inverse transform the predictions and actual values
    predictions = scaler.inverse_transform(predictions)
    y_test = scaler.inverse_transform(y_test.reshape(-1, 1))

    # Calculate SMAPE
    actual = sub_df[sub_df['product_name']==prod]['demand'][-18:].reset_index()
    smape = 1- smape_loss(actual['demand'], predictions)
    smape_list.append(smape)
    print(f'smape: {smape}')

results_df = pd.DataFrame({'product_name':rand_prods, 'accuracy':smape_list})
# Out:
# product_application gelb
# product_main_family C
# product_marketing_name hund
# product_basic_type BT294
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 1.0851
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8614
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6638
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4932
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4033
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3261
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2726
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2305
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2171
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2026
# 1/1 [==============================] - 0s 314ms/step
# smape: 0.4793127179145813
# product_application gelb
# product_main_family A
# product_marketing_name katze
# product_basic_type BT363
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 9ms/step - loss: 0.8968
# Epoch 2/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7184
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5874
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4860
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3893
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3276
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2700
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2331
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1973
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1868
# 1/1 [==============================] - 0s 376ms/step
# smape: 0.41336941719055176
# product_application blau
# product_main_family C
# product_marketing_name hund
# product_basic_type BT126
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.9495
# Epoch 2/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7246
# Epoch 3/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5892
# Epoch 4/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4422
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3450
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2989
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2519
# Epoch 8/10
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2414
# Epoch 9/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2199
# Epoch 10/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2071
# 1/1 [==============================] - 0s 361ms/step
# smape: 0.4077991843223572
# product_application gelb
# product_main_family A
# product_marketing_name katze
# product_basic_type BT348
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 1.0241
# Epoch 2/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.8521
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7182
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5974
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5088
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4305
# Epoch 7/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3653
# Epoch 8/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3126
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2709
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2325
# 1/1 [==============================] - 0s 355ms/step
# smape: 0.634291410446167
# product_application blau
# product_main_family Q
# product_marketing_name maus
# product_basic_type BT55
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 1.0104
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8716
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7090
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5812
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4563
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3977
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3201
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2745
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2225
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1860
# 1/1 [==============================] - 0s 366ms/step
# smape: 0.6719367504119873
# product_application rot
# product_main_family H
# product_marketing_name hund
# product_basic_type BT120
# cluster 0
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.9526
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.8134
# Epoch 3/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6717
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5825
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4790
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4125
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3416
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2862
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2525
# Epoch 10/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2242
# 1/1 [==============================] - 0s 434ms/step
# smape: 0.8431832790374756
# product_application blau
# product_main_family C
# product_marketing_name hund
# product_basic_type BT287
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 7ms/step - loss: 0.7082
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5341
# Epoch 3/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4318
# Epoch 4/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3556
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2986
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2947
# Epoch 7/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2676
# Epoch 8/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2497
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2476
# Epoch 10/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2540
# 1/1 [==============================] - 0s 491ms/step
# smape: 0.7612454891204834
# product_application gelb
# product_main_family A
# product_marketing_name katze
# product_basic_type BT369
# cluster 0
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.8987
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7439
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6080
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5011
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4143
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3511
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2912
# Epoch 8/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2338
# Epoch 9/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2113
# Epoch 10/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.1938
# 1/1 [==============================] - 0s 455ms/step
# smape: 0.4441806674003601
# product_application gelb
# product_main_family E
# product_marketing_name hund
# product_basic_type BT254
# cluster 6
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 11ms/step - loss: 1.0033
# Epoch 2/10
# 2/2 [==============================] - 0s 10ms/step - loss: 0.7453
# Epoch 3/10
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5789
# Epoch 4/10
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4599
# Epoch 5/10
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3566
# Epoch 6/10
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2681
# Epoch 7/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2618
# Epoch 8/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2208
# Epoch 9/10
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2060
# Epoch 10/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2228
# 1/1 [==============================] - 1s 637ms/step
# smape: 0.46652501821517944
# product_application rot
# product_main_family B
# product_marketing_name katze
# product_basic_type BT391
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.9035
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7040
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5584
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4026
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3118
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2747
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2403
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2128
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2130
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2359
# 1/1 [==============================] - 0s 338ms/step
# smape: 5.7816505432128906e-05
# product_application blau
# product_main_family D
# product_marketing_name hund
# product_basic_type BT266
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.7536
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6410
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5285
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4373
# Epoch 5/10
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3689
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2953
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2762
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2421
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2057
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2086
# 1/1 [==============================] - 0s 343ms/step
# smape: 0.8572608232498169
# product_application gelb
# product_main_family A
# product_marketing_name katze
# product_basic_type BT372
# cluster 0
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 1.0598
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9051
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7891
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6802
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5724
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5078
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4316
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3717
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3378
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2719
# 1/1 [==============================] - 0s 346ms/step
# smape: 0.4014433026313782
# product_application blau
# product_main_family A
# product_marketing_name katze
# product_basic_type BT339
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.8932
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7318
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6302
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5291
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4430
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3582
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3344
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2770
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2595
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2239
# 1/1 [==============================] - 0s 338ms/step
# smape: 0.7282724380493164
# product_application rot
# product_main_family B
# product_marketing_name katze
# product_basic_type BT386
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 3s 6ms/step - loss: 0.9604
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7162
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5874
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4538
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3497
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2910
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2390
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2483
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2177
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2101
# 1/1 [==============================] - 0s 338ms/step
# smape: 0.0012260675430297852
# product_application gelb
# product_main_family E
# product_marketing_name hund
# product_basic_type BT283
# cluster 3
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 1.1371
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9257
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7664
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6076
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5112
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4518
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3443
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3157
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2659
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2525
# 1/1 [==============================] - 0s 333ms/step
# smape: 0.16978389024734497
# product_application gelb
# product_main_family A
# product_marketing_name katze
# product_basic_type BT345
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 1.1875
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0386
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8230
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6721
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5950
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4865
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4091
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3463
# Epoch 9/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2825
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2484
# 1/1 [==============================] - 0s 335ms/step
# smape: 0.01454693078994751
# product_application blau
# product_main_family T
# product_marketing_name maus
# product_basic_type BT49
# cluster 0
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.8721
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7150
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5982
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4730
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3626
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3242
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2633
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2384
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2284
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2116
# 1/1 [==============================] - 0s 340ms/step
# smape: 0.22446155548095703
# product_application gelb
# product_main_family E
# product_marketing_name hund
# product_basic_type BT253
# cluster 4
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 7ms/step - loss: 1.1222
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9185
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7392
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6066
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4912
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4044
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3392
# Epoch 8/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3029
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2622
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2591
# 1/1 [==============================] - 0s 333ms/step
# smape: 0.29669320583343506
# product_application gelb
# product_main_family D
# product_marketing_name hund
# product_basic_type BT124
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 1.2584
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.9923
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8132
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6672
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5340
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4458
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3568
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2918
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2323
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2244
# 1/1 [==============================] - 0s 344ms/step
# smape: 0.22757327556610107
# product_application rot
# product_main_family B
# product_marketing_name katze
# product_basic_type BT386
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.7650
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5705
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4450
# Epoch 4/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3379
# Epoch 5/10
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2967
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2486
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2120
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2009
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2132
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2015
# 1/1 [==============================] - 0s 372ms/step
# smape: 0.0008230805397033691
# product_application blau
# product_main_family B
# product_marketing_name katze
# product_basic_type BT318
# cluster 0
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 7ms/step - loss: 0.8324
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6587
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5345
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4372
# Epoch 5/10
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3757
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3299
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2650
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2511
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2210
# Epoch 10/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2051
# 1/1 [==============================] - 0s 333ms/step
# smape: 0.046498656272888184
# product_application blau
# product_main_family J
# product_marketing_name hund
# product_basic_type BT266
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 1.2504
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9720
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8297
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6994
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5962
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5038
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4305
# Epoch 8/10
# 2/2 [==============================] - 0s 1ms/step - loss: 0.3489
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3194
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2732
# 1/1 [==============================] - 0s 420ms/step
# smape: 0.4938915967941284
# product_application gelb
# product_main_family A
# product_marketing_name katze
# product_basic_type BT350
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.6458
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5371
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4386
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3584
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2720
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2346
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1889
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1787
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1783
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1886
# 1/1 [==============================] - 0s 334ms/step
# smape: 0.5291825532913208
# product_application blau
# product_main_family Q
# product_marketing_name maus
# product_basic_type BT56
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.6300
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4970
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3928
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2948
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2176
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1891
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1683
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1846
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1707
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1862
# 1/1 [==============================] - 1s 1s/step
# smape: 0.5712532997131348
# product_application blau
# product_main_family T
# product_marketing_name maus
# product_basic_type BT52
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 8ms/step - loss: 0.9521
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7754
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6323
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5614
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4719
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4189
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3785
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3110
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2841
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2662
# 1/1 [==============================] - 0s 334ms/step
# smape: 0.7705387473106384
# product_application gelb
# product_main_family D
# product_marketing_name hund
# product_basic_type BT122
# cluster 0
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 7ms/step - loss: 0.8779
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6951
# Epoch 3/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5387
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4169
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3386
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2978
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2249
# Epoch 8/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2225
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1844
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1826
# 1/1 [==============================] - 0s 323ms/step
# smape: 0.3163118362426758
# product_application gelb
# product_main_family D
# product_marketing_name hund
# product_basic_type BT272
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.7874
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6456
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4958
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4071
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3255
# Epoch 6/10
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2638
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2065
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1870
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1744
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1857
# 1/1 [==============================] - 0s 411ms/step
# smape: 0.38331103324890137
# product_application blau
# product_main_family A
# product_marketing_name katze
# product_basic_type BT335
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 11ms/step - loss: 1.0874
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8690
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7326
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5944
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4797
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4137
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3547
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3062
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2648
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2633
# 1/1 [==============================] - 0s 336ms/step
# smape: 0.0017979741096496582
# product_application gelb
# product_main_family C
# product_marketing_name hund
# product_basic_type BT293
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.9330
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7531
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5863
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4551
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3690
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2944
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2456
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2221
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2006
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1918
# 1/1 [==============================] - 0s 331ms/step
# smape: 0.43047237396240234
# product_application rot
# product_main_family B
# product_marketing_name katze
# product_basic_type BT386
# cluster 6
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.8361
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6665
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4950
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3940
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3200
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2701
# Epoch 7/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2450
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2551
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2260
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2107
# 1/1 [==============================] - 0s 345ms/step
# smape: 0.6816482543945312
# product_application gelb
# product_main_family A
# product_marketing_name katze
# product_basic_type BT346
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 1.0546
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8800
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7286
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6180
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4665
# Epoch 6/10
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3945
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3207
# Epoch 8/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2585
# Epoch 9/10
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2379
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1976
# 1/1 [==============================] - 0s 345ms/step
# smape: 0.30897730588912964
# product_application gelb
# product_main_family C
# product_marketing_name hund
# product_basic_type BT142
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.7410
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5700
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4710
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3844
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3083
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2478
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2264
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2066
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1955
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2176
# 1/1 [==============================] - 0s 352ms/step
# smape: 0.23720771074295044
# product_application gelb
# product_main_family A
# product_marketing_name katze
# product_basic_type BT366
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 1.0283
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8323
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6896
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5926
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4992
# Epoch 6/10
# 2/2 [==============================] - 0s 1ms/step - loss: 0.4134
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3332
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2889
# Epoch 9/10
# 2/2 [==============================] - 0s 0s/step - loss: 0.2324
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2125
# 1/1 [==============================] - 0s 344ms/step
# smape: 0.10322576761245728
# product_application blau
# product_main_family B
# product_marketing_name katze
# product_basic_type BT315
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.9947
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7576
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6130
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5122
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3798
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3414
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3078
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2572
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2163
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2110
# 1/1 [==============================] - 0s 339ms/step
# smape: 0.4750019311904907
# product_application blau
# product_main_family R
# product_marketing_name fisch
# product_basic_type BT195
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 3s 5ms/step - loss: 0.7713
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6191
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4991
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4004
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3099
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2700
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2413
# Epoch 8/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2278
# Epoch 9/10
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2224
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2215
# 1/1 [==============================] - 0s 340ms/step
# smape: 0.40261709690093994
# product_application blau
# product_main_family K
# product_marketing_name maus
# product_basic_type BT70
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.8262
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6590
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5444
# Epoch 4/10
# 2/2 [==============================] - 0s 0s/step - loss: 0.4552
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3736
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3006
# Epoch 7/10
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2749
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2289
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2248
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2190
# 1/1 [==============================] - 0s 334ms/step
# smape: 0.16396528482437134
# product_application blau
# product_main_family I
# product_marketing_name maus
# product_basic_type BT218
# cluster 6
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.8853
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6998
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5598
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4750
# Epoch 5/10
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3740
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3149
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2708
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2334
# Epoch 9/10
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2252
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2218
# 1/1 [==============================] - 0s 325ms/step
# smape: 0.014526963233947754
# product_application blau
# product_main_family B
# product_marketing_name katze
# product_basic_type BT311
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 1.2193
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0149
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8324
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6996
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6089
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4983
# Epoch 7/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4223
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3720
# Epoch 9/10
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3156
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3050
# 1/1 [==============================] - 0s 388ms/step
# smape: 0.013789832592010498
# product_application blau
# product_main_family B
# product_marketing_name katze
# product_basic_type BT312
# cluster 0
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 1.2320
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9821
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8064
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6375
# Epoch 5/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5607
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4755
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3993
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3446
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3330
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3015
# 1/1 [==============================] - 0s 332ms/step
# smape: 0.0015218853950500488
# product_application gelb
# product_main_family A
# product_marketing_name katze
# product_basic_type BT364
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.9600
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7911
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6003
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5034
# Epoch 5/10
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3992
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3248
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2600
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2201
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1925
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1917
# 1/1 [==============================] - 0s 327ms/step
# smape: 0.23805582523345947
# product_application gelb
# product_main_family A
# product_marketing_name katze
# product_basic_type BT353
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.8591
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6990
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5893
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4987
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3981
# Epoch 6/10
# 2/2 [==============================] - 0s 0s/step - loss: 0.3348
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2803
# Epoch 8/10
# 2/2 [==============================] - 0s 11ms/step - loss: 0.2389
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2327
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1821
# 1/1 [==============================] - 0s 342ms/step
# smape: 0.0
# product_application blau
# product_main_family D
# product_marketing_name hund
# product_basic_type BT116
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 1.1442
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9428
# Epoch 3/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7569
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6402
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5298
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4366
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3623
# Epoch 8/10
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3177
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2888
# Epoch 10/10
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2508
# 1/1 [==============================] - 0s 336ms/step
# smape: 0.0
# product_application gelb
# product_main_family A
# product_marketing_name katze
# product_basic_type BT369
# cluster 0
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 1.2846
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0482
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8757
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6977
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5989
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5034
# Epoch 7/10
# 2/2 [==============================] - 0s 11ms/step - loss: 0.4173
# Epoch 8/10
# 2/2 [==============================] - 0s 10ms/step - loss: 0.3553
# Epoch 9/10
# 2/2 [==============================] - 0s 13ms/step - loss: 0.3182
# Epoch 10/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2847
# 1/1 [==============================] - 0s 374ms/step
# smape: 0.6265333890914917
# product_application blau
# product_main_family K
# product_marketing_name maus
# product_basic_type BT64
# cluster 0
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 1.4684
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 1.2053
# Epoch 3/10
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0165
# Epoch 4/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8562
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7190
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6075
# Epoch 7/10
# 2/2 [==============================] - 0s 0s/step - loss: 0.5257
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4528
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4000
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3460
# 1/1 [==============================] - 0s 349ms/step
# smape: 0.6304587125778198
# product_application blau
# product_main_family O
# product_marketing_name hund
# product_basic_type BT138
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 1.0486
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8303
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6220
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5213
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4131
# Epoch 6/10
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3339
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2773
# Epoch 8/10
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2495
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2036
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2014
# 1/1 [==============================] - 1s 1s/step
# smape: 0.6433150768280029
# product_application gelb
# product_main_family A
# product_marketing_name katze
# product_basic_type BT371
# cluster 0
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.8725
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6894
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5536
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4381
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3396
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2624
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2295
# Epoch 8/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2120
# Epoch 9/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1903
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1873
# 1/1 [==============================] - 0s 331ms/step
# smape: 0.022436022758483887
# product_application blau
# product_main_family B
# product_marketing_name katze
# product_basic_type BT314
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.8553
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6912
# Epoch 3/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5997
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4641
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3910
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3227
# Epoch 7/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2785
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2513
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2100
# Epoch 10/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2087
# 1/1 [==============================] - 0s 358ms/step
# smape: 0.007006645202636719
# product_application gelb
# product_main_family C
# product_marketing_name hund
# product_basic_type BT288
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 1.3139
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0589
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8246
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7035
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5788
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4681
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3973
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3266
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2806
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2452
# 1/1 [==============================] - 0s 332ms/step
# smape: 0.19921374320983887
# product_application gelb
# product_main_family H
# product_marketing_name hund
# product_basic_type BT119
# cluster 0
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 1.2046
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9794
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8451
# Epoch 4/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6908
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5909
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4896
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4247
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3276
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2668
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2190
# 1/1 [==============================] - 0s 343ms/step
# smape: 0.7550866007804871
# product_application blau
# product_main_family B
# product_marketing_name katze
# product_basic_type BT312
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.7467
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6352
# Epoch 3/10
# ...
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2811
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2355
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2256
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2013
# 1/1 [==============================] - 0s 403ms/step
# smape: 0.18713033199310303
# product_application rot
# product_main_family B
# product_marketing_name katze
# product_basic_type BT390
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 7ms/step - loss: 0.9634
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8198
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6477
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5508
# Epoch 5/10
# 2/2 [==============================] - 0s 1ms/step - loss: 0.4623
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3698
# Epoch 7/10
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3428
# Epoch 8/10
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2923
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2564
# Epoch 10/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2284
# 1/1 [==============================] - 0s 348ms/step
# smape: 0.009900927543640137
# product_application gelb
# product_main_family A
# product_marketing_name katze
# product_basic_type BT350
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 1.0380
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8431
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6887
# Epoch 4/10
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5763
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4820
# Epoch 6/10
# 2/2 [==============================] - 0s 0s/step - loss: 0.3815
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2958
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2697
# Epoch 9/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2114
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1879
# 1/1 [==============================] - 0s 350ms/step
# smape: 0.15630239248275757
# product_application gelb
# product_main_family D
# product_marketing_name hund
# product_basic_type BT274
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.7346
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5819
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4694
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3622
# Epoch 5/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2798
# Epoch 6/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2122
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1628
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1598
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1663
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1611
# 1/1 [==============================] - 1s 1s/step
# smape: 0.4325065612792969
# product_application gelb
# product_main_family A
# product_marketing_name katze
# product_basic_type BT363
# cluster 0
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 7ms/step - loss: 0.8950
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7237
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5719
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4995
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3811
# Epoch 6/10
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3356
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2708
# Epoch 8/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.2377
# Epoch 9/10
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1931
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1752
# 1/1 [==============================] - 0s 447ms/step
# smape: 0.13365936279296875
# product_application blau
# product_main_family D
# product_marketing_name hund
# product_basic_type BT264
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 7ms/step - loss: 1.0024
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.8308
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6905
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5614
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4818
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4004
# Epoch 7/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3345
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2870
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2568
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2016
# 1/1 [==============================] - 0s 350ms/step
# smape: 0.708105206489563
# product_application gelb
# product_main_family J
# product_marketing_name hund
# product_basic_type BT101
# cluster 0
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 1.3620
# Epoch 2/10
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0912
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.9125
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7717
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6393
# Epoch 6/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5515
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4677
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3822
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3385
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2947
# 1/1 [==============================] - 0s 450ms/step
# smape: 0.21114760637283325
# product_application gelb
# product_main_family A
# product_marketing_name katze
# product_basic_type BT370
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.8290
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6820
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5219
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4260
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3455
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2712
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2164
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2106
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1917
# Epoch 10/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2045
# 1/1 [==============================] - 0s 343ms/step
# smape: 0.0
# product_application blau
# product_main_family U
# product_marketing_name fisch
# product_basic_type BT418
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.7315
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5930
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4958
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4252
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3334
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2825
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2526
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2111
# Epoch 9/10
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1943
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2086
# 1/1 [==============================] - 0s 451ms/step
# smape: 4.887580871582031e-05
# product_application gelb
# product_main_family C
# product_marketing_name hund
# product_basic_type BT158
# cluster 0
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 1.0644
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8768
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7326
# Epoch 4/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6030
# Epoch 5/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5060
# Epoch 6/10
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4035
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3373
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2707
# Epoch 9/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.2335
# Epoch 10/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2275
# 1/1 [==============================] - 0s 370ms/step
# smape: 0.0
# product_application blau
# product_main_family A
# product_marketing_name katze
# product_basic_type BT339
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.7473
# Epoch 2/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5774
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4643
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3952
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3042
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2319
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2279
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1913
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2048
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.1875
# 1/1 [==============================] - 0s 469ms/step
# smape: 0.6915282011032104
# product_application blau
# product_main_family F
# product_marketing_name hund
# product_basic_type BT162
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 1.0720
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8477
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7000
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5896
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4796
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4064
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3441
# Epoch 8/10
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3044
# Epoch 9/10
# 2/2 [==============================] - 0s 2ms/step - loss: 0.2486
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2341
# 1/1 [==============================] - 0s 352ms/step
# smape: 0.7077807188034058
# product_application blau
# product_main_family A
# product_marketing_name katze
# product_basic_type BT340
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.9898
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7617
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6162
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4876
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4194
# Epoch 6/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3377
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.3078
# Epoch 8/10
# 2/2 [==============================] - 0s 7ms/step - loss: 0.2558
# Epoch 9/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2307
# Epoch 10/10
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2267
# 1/1 [==============================] - 0s 451ms/step
# smape: 0.7398321628570557
# product_application blau
# product_main_family K
# product_marketing_name maus
# product_basic_type BT65
# cluster 0
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.8935
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6875
# Epoch 3/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5571
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4428
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3545
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3296
# Epoch 7/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.2738
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2590
# Epoch 9/10
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2306
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2332
# 1/1 [==============================] - 0s 344ms/step
# smape: 0.0006663203239440918
# product_application blau
# product_main_family K
# product_marketing_name maus
# product_basic_type BT62
# cluster 6
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 3s 7ms/step - loss: 1.1127
# Epoch 2/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.9210
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7592
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6361
# Epoch 5/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5433
# Epoch 6/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.4682
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4107
# Epoch 8/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3693
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3462
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3187
# 1/1 [==============================] - 0s 437ms/step
# smape: 0.06711429357528687
# product_application blau
# product_main_family A
# product_marketing_name katze
# product_basic_type BT337
# cluster 0
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 6ms/step - loss: 0.7987
# Epoch 2/10
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6447
# Epoch 3/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5333
# Epoch 4/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4165
# Epoch 5/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3393
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2794
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2302
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2057
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2060
# Epoch 10/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.1832
# 1/1 [==============================] - 0s 354ms/step
# smape: 0.5728636980056763
# product_application blau
# product_main_family J
# product_marketing_name hund
# product_basic_type BT265
# cluster 5
# shaped
# built
# Epoch 1/10
# 2/2 [==============================] - 2s 5ms/step - loss: 0.8513
# Epoch 2/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6822
# Epoch 3/10
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5503
# Epoch 4/10
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4509
# Epoch 5/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3802
# Epoch 6/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3272
# Epoch 7/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2627
# Epoch 8/10
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2438
# Epoch 9/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2090
# Epoch 10/10
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2070
# 1/1 [==============================] - 0s 451ms/step
# smape: 0.7523136138916016

# %%
results_df['accuracy'] = results_df['accuracy'].apply(lambda x:float(x))
counts, edges, bars = plt.hist(results_df['accuracy'])
plt.bar_label(container=bars)
plt.title(f'Histogram of accuracy score (n=100, at least 30 data points), Avg Accuracy = {round(results_df["accuracy"].mean(), 4)}')
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
results_df.to_csv('cold_start_clus.csv')
